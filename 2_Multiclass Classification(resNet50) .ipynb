# %%
# 필요한 모듈 import하기

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import activations
from tensorflow.keras.applications import EfficientNetB0

from glob import glob
from pprint import pprint

import os
import math
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_hub as hub
from keras.models import load_model

# %%
csv_path = './feelings_skfold2.csv'
df = pd.read_csv(csv_path)
np.unique(df['emotion'])

value_counts = df['emotion'].value_counts().sort_index()
plt.figure(figsize=(10, 5))
plt.bar(range(len(value_counts)), value_counts.values)
plt.xticks(range(len(value_counts)), value_counts.index.values)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 1. Model 정의하기

# %% [markdown]
# * binary crossentropy : binary 다중 분류 손실 함수 -> label들이 독립적일 때 사용함
# * categorical_crossentropy : 다중 분류 손실 함수, 출력값이 one-hot encoding된 결과로 나옴
# * (정답에만 1으로 표시하고, 나머지는 0으로)
# * 각 샘플이 정확히 하나의 클래스에 속하는 경우 사용한다.
# * sparse_categorical_crossentropy : 다중 분류 손실 함수, one - hot - encoding을 하지 않고 정수 형태로 넣어줌, 한 샘플에 여러 클래스가 있거나 label이 soft 확률일 경우 사용

# %% [markdown]
# * softmax
# - 출력은 0 ~ 1 사이의 실수
# - 출력을 확률로 해석할 수 있음
# - 출력의 총합은 1이다.

# %% [markdown]
# # Tensorflow Hub

# %% [markdown]
# * https://tfhub.dev/
# * 조정 및 배포 가능한 학습된 머신러닝 모델의 저장소
# * 단 몇 줄의 코드만으로 BERT 및 CNN과 같은 학습된 모델을 재사용할 수 있음

# %%
model = tf.keras.Sequential([
    hub.KerasLayer("https://tfhub.dev/google/imagenet/resnet_v2_50/classification/5",
                  trainable = True), # pre-trained model 불러오기
    tf.keras.layers.Dense(7,activation = 'softmax')
])
model.build([None,48,48,3]) # 4차원 형태

adam = keras.optimizers.Adam(lr = 0.0001)
model.compile(
    optimizer = adam,
    loss = 'sparse_categorical_crossentropy', # 정수 형태로 label 전달
    metrics = 'accuracy'
)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  keras_layer (KerasLayer)    (None, 1001)              25615849
#
#  dense (Dense)               (None, 7)                 7014
#
# =================================================================
# Total params: 25,622,863
# Trainable params: 25,577,423
# Non-trainable params: 45,440
# _________________________________________________________________
# c:\users\doroc\appdata\local\programs\python\python38\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
import albumentations as A

# Albumentation class 생성하기
class Augmentation:
    def __init__(self, size, mode='train'):
        if mode == 'train':
            self.transform = A.Compose([
                # 수평 전환
                A.HorizontalFlip(p=0.5),
                # 이동, 크기, 회전을 설정
                A.ShiftScaleRotate(
                    p=0.5,
                    shift_limit=0.05,
                    scale_limit=0.05,
                    rotate_limit=15
                ),
                # 구멍을 dropout 하게됨
                A.CoarseDropout(
                    p=0.5,
                    max_holes=8, # 최대 8개의 구멍을 dropout 시킴
                    max_height=int(0.1 * size),
                    max_width=int(0.1 * size)
                ),
                A.RandomBrightnessContrast(p=0.2) # 밝기 대비
            ])
    
    def __call__(self, **kwargs): # callback 함수: 클래스의 객체를 생성한 이후 객체를 호출할 떄 자동으로 실행되는 함수
        if self.transform:
            augmented = self.transform(**kwargs) # **kwargs : 가변 인수(파라미터의 개수에 제한을 두지 않겠다.)
            img = augmented['image'] # 증폭된 이미지
            return img

# %%
csv_path = './feelings_skfold2.csv'

LABEL_INT_DICT = np.unique(pd.read_csv(csv_path)['emotion'])
pprint(LABEL_INT_DICT) # 데이터의 타입과 형태 등도 같이 보여준다.(조금 더 예쁘게 출력해준다?)
LABEL_STR_DICT = {k:v for v,k in enumerate(LABEL_INT_DICT)}
pprint(LABEL_STR_DICT)
# Out:
# array(['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise'],
#       dtype=object)
# {'angry': 0,
#  'disgust': 1,
#  'fear': 2,
#  'happy': 3,
#  'neutral': 4,
#  'sad': 5,
#  'surprise': 6}

# %%
class DataGenerator(keras.utils.Sequence):
    def __init__(self, batch_size, csv_path, fold, image_size, mode='train', shuffle=True):
        self.batch_size = batch_size
        self.fold = fold
        self.image_size = image_size
        self.mode = mode
        self.shuffle = shuffle
        
        self.df = pd.read_csv(csv_path)
        
        if self.mode == 'train':
            self.df = self.df[self.df['fold'] != self.fold]
        elif self.mode == 'val':
            self.df = self.df[self.df['fold'] == self.fold]
            
        self.transform = Augmentation(image_size, mode)
        
        self.on_epoch_end()

        
    def on_epoch_end(self):
        if self.shuffle: # shuffle = True라면(df 앞의 인덱스를 지워주는 기능
            self.df = self.df.sample(frac=1).reset_index(drop=True)
    # len()
    def __len__(self):
            return math.ceil(len(self.df) / self.batch_size)

    def __getitem__(self, idx):
        strt = idx * self.batch_size
        fin = (idx + 1) * self.batch_size
        data = self.df.iloc[strt:fin]
        batch_x, batch_y = self.get_data(data)
        return np.array(batch_x), np.array(batch_y)
        
    def get_data(self, data):
        batch_x = []
        batch_y = []
        
        for _, r in data.iterrows():
            file_name = r['file_name']
            img_folder = r['emotion'] # type = np.str_

            image = cv2.imread(f'datasets2/{img_folder}/{file_name}.jpg',cv2.IMREAD_GRAYSCALE)
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            image = cv2.resize(image, (self.image_size, self.image_size))
            
            if self.mode == 'train':
                image = image.astype('uint8') # 정수로 형변환
                image = self.transform(image=image)

            image = image.astype('float32') # 실수로 다시 형변환         
            image = image / 255.

            
            emotion = str(img_folder)
            emotion = LABEL_STR_DICT[emotion]
            
            batch_x.append(image)
            batch_y.append(emotion)
        
        return batch_x, batch_y

# %%
csv_path = './feelings_skfold2.csv'

train_generator = DataGenerator(
    batch_size = 128,
    csv_path = csv_path,
    fold = 1,
    image_size = 48,
    mode = 'train',
    shuffle = True
)

valid_generator = DataGenerator(
    batch_size = 128,
    csv_path = csv_path,
    fold = 1, 
    image_size = 48,
    mode = 'val',
    shuffle = True
)

# %%
history = model.fit(
    train_generator,
    validation_data = valid_generator,
    epochs = 50,
    verbose = 1
)
# Out:
# Epoch 1/50
# 111/111 [==============================] - 268s 2s/step - loss: 2.3899 - accuracy: 0.1928 - val_loss: 2.2282 - val_accuracy: 0.2404
# Epoch 2/50
# 111/111 [==============================] - 264s 2s/step - loss: 2.1307 - accuracy: 0.2979 - val_loss: 1.9827 - val_accuracy: 0.3761
# Epoch 3/50
# 111/111 [==============================] - 263s 2s/step - loss: 1.9512 - accuracy: 0.3826 - val_loss: 1.8066 - val_accuracy: 0.4467
# Epoch 4/50
# 111/111 [==============================] - 263s 2s/step - loss: 1.8199 - accuracy: 0.4375 - val_loss: 1.6943 - val_accuracy: 0.4904
# Epoch 5/50
# 111/111 [==============================] - 262s 2s/step - loss: 1.7307 - accuracy: 0.4796 - val_loss: 1.6434 - val_accuracy: 0.5045
# Epoch 6/50
# 111/111 [==============================] - 263s 2s/step - loss: 1.6336 - accuracy: 0.5132 - val_loss: 1.6094 - val_accuracy: 0.5313
# Epoch 7/50
# 111/111 [==============================] - 263s 2s/step - loss: 1.5680 - accuracy: 0.5385 - val_loss: 1.5812 - val_accuracy: 0.5505
# Epoch 8/50
# 111/111 [==============================] - 262s 2s/step - loss: 1.4961 - accuracy: 0.5746 - val_loss: 1.5765 - val_accuracy: 0.5511
# Epoch 9/50
# 111/111 [==============================] - 262s 2s/step - loss: 1.4449 - accuracy: 0.5903 - val_loss: 1.5824 - val_accuracy: 0.5519
# Epoch 10/50
# 111/111 [==============================] - 263s 2s/step - loss: 1.3780 - accuracy: 0.6149 - val_loss: 1.5586 - val_accuracy: 0.5663
# Epoch 11/50
# 111/111 [==============================] - 263s 2s/step - loss: 1.3280 - accuracy: 0.6353 - val_loss: 1.5975 - val_accuracy: 0.5522
# Epoch 12/50
# 111/111 [==============================] - 262s 2s/step - loss: 1.2821 - accuracy: 0.6558 - val_loss: 1.6154 - val_accuracy: 0.5612
# Epoch 13/50
# 111/111 [==============================] - 264s 2s/step - loss: 1.2305 - accuracy: 0.6725 - val_loss: 1.6306 - val_accuracy: 0.5657
# Epoch 14/50
# 111/111 [==============================] - 263s 2s/step - loss: 1.1653 - accuracy: 0.6946 - val_loss: 1.6407 - val_accuracy: 0.5624
# Epoch 15/50
# 111/111 [==============================] - 262s 2s/step - loss: 1.1269 - accuracy: 0.7133 - val_loss: 1.7248 - val_accuracy: 0.5669
# Epoch 16/50
# 111/111 [==============================] - 262s 2s/step - loss: 1.0860 - accuracy: 0.7300 - val_loss: 1.6710 - val_accuracy: 0.5818
# Epoch 17/50
# 111/111 [==============================] - 263s 2s/step - loss: 1.0350 - accuracy: 0.7475 - val_loss: 1.7423 - val_accuracy: 0.5683
# Epoch 18/50
# 111/111 [==============================] - 263s 2s/step - loss: 1.0048 - accuracy: 0.7588 - val_loss: 1.7780 - val_accuracy: 0.5725
# Epoch 19/50
# 111/111 [==============================] - 263s 2s/step - loss: 0.9594 - accuracy: 0.7737 - val_loss: 1.7695 - val_accuracy: 0.5765
# Epoch 20/50
# 111/111 [==============================] - 262s 2s/step - loss: 0.9165 - accuracy: 0.7916 - val_loss: 1.8655 - val_accuracy: 0.5765
# Epoch 21/50
# 111/111 [==============================] - 263s 2s/step - loss: 0.8852 - accuracy: 0.8032 - val_loss: 1.8135 - val_accuracy: 0.5815
# Epoch 22/50
# 111/111 [==============================] - 262s 2s/step - loss: 0.8522 - accuracy: 0.8137 - val_loss: 1.8518 - val_accuracy: 0.5807
# Epoch 23/50
# 111/111 [==============================] - 263s 2s/step - loss: 0.8227 - accuracy: 0.8252 - val_loss: 1.9313 - val_accuracy: 0.5821
# Epoch 24/50
# 111/111 [==============================] - 262s 2s/step - loss: 0.8160 - accuracy: 0.8274 - val_loss: 1.9379 - val_accuracy: 0.5688
# Epoch 25/50
# 111/111 [==============================] - 263s 2s/step - loss: 0.7733 - accuracy: 0.8403 - val_loss: 1.9715 - val_accuracy: 0.5790
# Epoch 26/50
# 111/111 [==============================] - 262s 2s/step - loss: 0.7604 - accuracy: 0.8450 - val_loss: 2.0002 - val_accuracy: 0.5686
# Epoch 27/50
# 111/111 [==============================] - 264s 2s/step - loss: 0.7346 - accuracy: 0.8572 - val_loss: 2.0066 - val_accuracy: 0.5894
# Epoch 28/50
# 111/111 [==============================] - 267s 2s/step - loss: 0.7152 - accuracy: 0.8631 - val_loss: 2.0286 - val_accuracy: 0.5731
# Epoch 29/50
# 111/111 [==============================] - 263s 2s/step - loss: 0.6993 - accuracy: 0.8715 - val_loss: 2.0352 - val_accuracy: 0.5886
# Epoch 30/50
# 111/111 [==============================] - 263s 2s/step - loss: 0.6886 - accuracy: 0.8715 - val_loss: 2.1373 - val_accuracy: 0.5652
# Epoch 31/50
# 111/111 [==============================] - 263s 2s/step - loss: 0.6497 - accuracy: 0.8862 - val_loss: 2.0884 - val_accuracy: 0.5717
# Epoch 32/50
# 111/111 [==============================] - 263s 2s/step - loss: 0.6510 - accuracy: 0.8843 - val_loss: 2.1018 - val_accuracy: 0.5920
# Epoch 33/50
# 111/111 [==============================] - 263s 2s/step - loss: 0.6438 - accuracy: 0.8902 - val_loss: 2.1773 - val_accuracy: 0.5657
# Epoch 34/50
# 111/111 [==============================] - 263s 2s/step - loss: 0.6240 - accuracy: 0.8954 - val_loss: 2.1629 - val_accuracy: 0.5779
# Epoch 35/50
# 111/111 [==============================] - 264s 2s/step - loss: 0.6196 - accuracy: 0.8962 - val_loss: 2.1436 - val_accuracy: 0.5875
# Epoch 36/50
# 111/111 [==============================] - 263s 2s/step - loss: 0.5986 - accuracy: 0.9028 - val_loss: 2.1417 - val_accuracy: 0.5920
# Epoch 37/50
# 111/111 [==============================] - 262s 2s/step - loss: 0.5951 - accuracy: 0.9031 - val_loss: 2.2300 - val_accuracy: 0.5900
# Epoch 38/50
# 111/111 [==============================] - 263s 2s/step - loss: 0.5930 - accuracy: 0.9032 - val_loss: 2.2557 - val_accuracy: 0.5880
# Epoch 39/50
# 111/111 [==============================] - 263s 2s/step - loss: 0.5830 - accuracy: 0.9081 - val_loss: 2.1641 - val_accuracy: 0.5931
# Epoch 40/50
# 111/111 [==============================] - 264s 2s/step - loss: 0.5639 - accuracy: 0.9128 - val_loss: 2.1923 - val_accuracy: 0.5903
# Epoch 41/50
# 111/111 [==============================] - 263s 2s/step - loss: 0.5523 - accuracy: 0.9167 - val_loss: 2.2450 - val_accuracy: 0.5903
# Epoch 42/50
# 111/111 [==============================] - 262s 2s/step - loss: 0.5582 - accuracy: 0.9148 - val_loss: 2.2422 - val_accuracy: 0.5838
# Epoch 43/50
# 111/111 [==============================] - 263s 2s/step - loss: 0.5559 - accuracy: 0.9160 - val_loss: 2.3039 - val_accuracy: 0.5756
# Epoch 44/50
# 111/111 [==============================] - 262s 2s/step - loss: 0.5453 - accuracy: 0.9196 - val_loss: 2.2591 - val_accuracy: 0.5784
# Epoch 45/50
# 111/111 [==============================] - 263s 2s/step - loss: 0.5396 - accuracy: 0.9214 - val_loss: 2.2928 - val_accuracy: 0.5914
# Epoch 46/50
# 111/111 [==============================] - 263s 2s/step - loss: 0.5333 - accuracy: 0.9220 - val_loss: 2.3743 - val_accuracy: 0.5793
# Epoch 47/50
# 111/111 [==============================] - 263s 2s/step - loss: 0.5258 - accuracy: 0.9232 - val_loss: 2.2150 - val_accuracy: 0.5996
# Epoch 48/50
# 111/111 [==============================] - 263s 2s/step - loss: 0.5194 - accuracy: 0.9263 - val_loss: 2.3613 - val_accuracy: 0.5954
# Epoch 49/50
# 111/111 [==============================] - 262s 2s/step - loss: 0.5111 - accuracy: 0.9300 - val_loss: 2.3705 - val_accuracy: 0.5866
# Epoch 50/50
# 111/111 [==============================] - 262s 2s/step - loss: 0.5025 - accuracy: 0.9303 - val_loss: 2.4048 - val_accuracy: 0.5779

# %%
history = history.history

plt.figure(figsize=(25, 10))
plt.subplot(1, 2, 1)
plt.plot(history['loss'], label='train')
plt.plot(history['val_loss'], label='val')
plt.legend()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.title("Loss")

plt.subplot(1, 2, 2)
plt.plot(history['accuracy'], label='train')
plt.plot(history['val_accuracy'], label='val')
plt.legend()
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.title("Accuracy")
plt.show()

# %%
train_generator2 = DataGenerator(
    batch_size = 64,
    csv_path = csv_path,
    fold = 1,
    image_size = 48,
    mode = 'train',
    shuffle = True
)

valid_generator2 = DataGenerator(
    batch_size = 64,
    csv_path = csv_path,
    fold = 1, 
    image_size = 48,
    mode = 'val',
    shuffle = True
)

# %%
history2 = model.fit(
    train_generator2,
    validation_data = valid_generator2,
    epochs = 50,
    verbose = 1
)
# Out:
# Epoch 1/50
# 222/222 [==============================] - 293s 1s/step - loss: 0.7252 - accuracy: 0.8551 - val_loss: 2.1955 - val_accuracy: 0.5570
# Epoch 2/50
# 222/222 [==============================] - 284s 1s/step - loss: 0.7280 - accuracy: 0.8541 - val_loss: 2.1072 - val_accuracy: 0.5799
# Epoch 3/50
# 222/222 [==============================] - 283s 1s/step - loss: 0.6882 - accuracy: 0.8689 - val_loss: 2.0836 - val_accuracy: 0.5827
# Epoch 4/50
# 222/222 [==============================] - 283s 1s/step - loss: 0.6313 - accuracy: 0.8863 - val_loss: 2.1731 - val_accuracy: 0.5790
# Epoch 5/50
# 222/222 [==============================] - 284s 1s/step - loss: 0.6088 - accuracy: 0.8953 - val_loss: 2.2807 - val_accuracy: 0.5796
# Epoch 6/50
# 222/222 [==============================] - 284s 1s/step - loss: 0.6095 - accuracy: 0.8971 - val_loss: 2.1705 - val_accuracy: 0.5832
# Epoch 7/50
# 222/222 [==============================] - 284s 1s/step - loss: 0.5875 - accuracy: 0.9039 - val_loss: 2.2711 - val_accuracy: 0.5911
# Epoch 8/50
# 222/222 [==============================] - 283s 1s/step - loss: 0.5861 - accuracy: 0.9036 - val_loss: 2.2722 - val_accuracy: 0.5815
# Epoch 9/50
# 222/222 [==============================] - 284s 1s/step - loss: 0.5755 - accuracy: 0.9076 - val_loss: 2.2269 - val_accuracy: 0.5793
# Epoch 10/50
# 222/222 [==============================] - 284s 1s/step - loss: 0.5612 - accuracy: 0.9115 - val_loss: 2.2435 - val_accuracy: 0.5962
# Epoch 11/50
# 222/222 [==============================] - 284s 1s/step - loss: 0.5623 - accuracy: 0.9131 - val_loss: 2.2996 - val_accuracy: 0.5745
# Epoch 12/50
# 222/222 [==============================] - 283s 1s/step - loss: 0.5607 - accuracy: 0.9132 - val_loss: 2.2857 - val_accuracy: 0.5813
# Epoch 13/50
# 222/222 [==============================] - 284s 1s/step - loss: 0.5501 - accuracy: 0.9162 - val_loss: 2.3172 - val_accuracy: 0.5756
# Epoch 14/50
# 222/222 [==============================] - 284s 1s/step - loss: 0.5338 - accuracy: 0.9220 - val_loss: 2.3334 - val_accuracy: 0.5799
# Epoch 15/50
# 222/222 [==============================] - 284s 1s/step - loss: 0.5328 - accuracy: 0.9215 - val_loss: 2.3276 - val_accuracy: 0.5844
# Epoch 16/50
# 222/222 [==============================] - 284s 1s/step - loss: 0.5357 - accuracy: 0.9213 - val_loss: 2.4218 - val_accuracy: 0.5827
# Epoch 17/50
# 222/222 [==============================] - 284s 1s/step - loss: 0.5482 - accuracy: 0.9172 - val_loss: 2.3350 - val_accuracy: 0.5911
# Epoch 18/50
# 222/222 [==============================] - 283s 1s/step - loss: 0.5203 - accuracy: 0.9254 - val_loss: 2.2817 - val_accuracy: 0.5832
# Epoch 19/50
# 222/222 [==============================] - 284s 1s/step - loss: 0.5049 - accuracy: 0.9272 - val_loss: 2.3611 - val_accuracy: 0.5923
# Epoch 20/50
# 222/222 [==============================] - 284s 1s/step - loss: 0.5106 - accuracy: 0.9280 - val_loss: 2.3984 - val_accuracy: 0.5838
# Epoch 21/50
# 222/222 [==============================] - 283s 1s/step - loss: 0.5209 - accuracy: 0.9274 - val_loss: 2.3271 - val_accuracy: 0.5886
# Epoch 22/50
# 222/222 [==============================] - 283s 1s/step - loss: 0.5063 - accuracy: 0.9294 - val_loss: 2.4545 - val_accuracy: 0.5844
# Epoch 23/50
# 222/222 [==============================] - 284s 1s/step - loss: 0.5062 - accuracy: 0.9316 - val_loss: 2.3797 - val_accuracy: 0.5894
# Epoch 24/50
# 222/222 [==============================] - 284s 1s/step - loss: 0.5059 - accuracy: 0.9304 - val_loss: 2.4984 - val_accuracy: 0.5965
# Epoch 25/50
# 222/222 [==============================] - 283s 1s/step - loss: 0.5120 - accuracy: 0.9262 - val_loss: 2.3401 - val_accuracy: 0.5917
# Epoch 26/50
# 222/222 [==============================] - 284s 1s/step - loss: 0.4978 - accuracy: 0.9327 - val_loss: 2.3520 - val_accuracy: 0.5892
# Epoch 27/50
# 222/222 [==============================] - 283s 1s/step - loss: 0.5049 - accuracy: 0.9328 - val_loss: 2.4367 - val_accuracy: 0.5954
# Epoch 28/50
# 222/222 [==============================] - 283s 1s/step - loss: 0.5061 - accuracy: 0.9305 - val_loss: 2.4172 - val_accuracy: 0.5923
# Epoch 29/50
# 222/222 [==============================] - 284s 1s/step - loss: 0.4944 - accuracy: 0.9355 - val_loss: 2.4415 - val_accuracy: 0.5861
# Epoch 30/50
# 222/222 [==============================] - 285s 1s/step - loss: 0.4909 - accuracy: 0.9373 - val_loss: 2.4185 - val_accuracy: 0.5849
# Epoch 31/50
# 222/222 [==============================] - 284s 1s/step - loss: 0.4840 - accuracy: 0.9364 - val_loss: 2.4371 - val_accuracy: 0.5911
# Epoch 32/50
# 222/222 [==============================] - 283s 1s/step - loss: 0.4897 - accuracy: 0.9362 - val_loss: 2.4183 - val_accuracy: 0.5753
# Epoch 33/50
# 222/222 [==============================] - 284s 1s/step - loss: 0.4818 - accuracy: 0.9388 - val_loss: 2.4633 - val_accuracy: 0.5776
# Epoch 34/50
# 222/222 [==============================] - 283s 1s/step - loss: 0.4816 - accuracy: 0.9405 - val_loss: 2.5153 - val_accuracy: 0.5968
# Epoch 35/50
# 222/222 [==============================] - 283s 1s/step - loss: 0.4833 - accuracy: 0.9400 - val_loss: 2.3688 - val_accuracy: 0.5911
# Epoch 36/50
# 222/222 [==============================] - 283s 1s/step - loss: 0.4809 - accuracy: 0.9409 - val_loss: 2.4848 - val_accuracy: 0.5782
# Epoch 37/50
# 222/222 [==============================] - 284s 1s/step - loss: 0.4667 - accuracy: 0.9438 - val_loss: 2.4330 - val_accuracy: 0.6024
# Epoch 38/50
# 222/222 [==============================] - 283s 1s/step - loss: 0.4627 - accuracy: 0.9463 - val_loss: 2.4424 - val_accuracy: 0.5875
# Epoch 39/50
# 222/222 [==============================] - 284s 1s/step - loss: 0.4676 - accuracy: 0.9451 - val_loss: 2.5014 - val_accuracy: 0.5886
# Epoch 40/50
# 222/222 [==============================] - 283s 1s/step - loss: 0.4673 - accuracy: 0.9438 - val_loss: 2.4351 - val_accuracy: 0.5906
# Epoch 41/50
# 222/222 [==============================] - 283s 1s/step - loss: 0.4717 - accuracy: 0.9462 - val_loss: 2.4176 - val_accuracy: 0.5909
# Epoch 42/50
# 222/222 [==============================] - 283s 1s/step - loss: 0.4601 - accuracy: 0.9474 - val_loss: 2.4825 - val_accuracy: 0.5889
# Epoch 43/50
# 222/222 [==============================] - 283s 1s/step - loss: 0.4704 - accuracy: 0.9450 - val_loss: 2.5324 - val_accuracy: 0.5858
# Epoch 44/50
# 222/222 [==============================] - 283s 1s/step - loss: 0.4612 - accuracy: 0.9468 - val_loss: 2.5656 - val_accuracy: 0.5855
# Epoch 45/50
# 222/222 [==============================] - 283s 1s/step - loss: 0.4596 - accuracy: 0.9479 - val_loss: 2.6417 - val_accuracy: 0.5875
# Epoch 46/50
# 222/222 [==============================] - 282s 1s/step - loss: 0.4719 - accuracy: 0.9437 - val_loss: 2.4729 - val_accuracy: 0.5914
# Epoch 47/50
# 222/222 [==============================] - 283s 1s/step - loss: 0.4639 - accuracy: 0.9460 - val_loss: 2.4504 - val_accuracy: 0.5926
# Epoch 48/50
# 222/222 [==============================] - 284s 1s/step - loss: 0.4678 - accuracy: 0.9419 - val_loss: 2.4356 - val_accuracy: 0.5872
# Epoch 49/50
# 222/222 [==============================] - 283s 1s/step - loss: 0.4613 - accuracy: 0.9480 - val_loss: 2.4567 - val_accuracy: 0.5883
# Epoch 50/50
# 222/222 [==============================] - 283s 1s/step - loss: 0.4418 - accuracy: 0.9541 - val_loss: 2.5222 - val_accuracy: 0.5954

# %%
history2 = history2.history

plt.figure(figsize=(25, 10))
plt.subplot(1, 2, 1)
plt.plot(history2['loss'], label='train')
plt.plot(history2['val_loss'], label='val')
plt.legend()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.title("Loss")

plt.subplot(1, 2, 2)
plt.plot(history2['accuracy'], label='train')
plt.plot(history2['val_accuracy'], label='val')
plt.legend()
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.title("Accuracy")
plt.show()

# %%
model.save('emotion_model_resNet50.h5') # 학습 결과 저장하기
